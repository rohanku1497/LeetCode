# %%
s = "suresh ramesh vibhuti gulgule raji ram shyam ajay"

# %%
l=s.split(" ")

# %%
l
# Out:
# ['suresh', 'ramesh', 'vibhuti', 'gulgule', 'raji', 'ram', 'shyam', 'ajay']

# %%
l.sort(key=lambda x : x[0])

# %%
x=" ".join(l)

# %%
x
# Out:
# 'ajay gulgule raji ram ramesh shyam suresh vibhuti'

# %%
n=[30,10,45,5,20]

# %%
n.sort()

# %%
n[-2]
# Out:
# 30
