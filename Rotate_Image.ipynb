# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
matrix=matrix[::-1]
x=[list(row) for row in zip(*matrix)]
x
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
matrix.reverse()
matrix=list(zip(*matrix))
matrix
# Out:
# [(7, 4, 1), (8, 5, 2), (9, 6, 3)]
