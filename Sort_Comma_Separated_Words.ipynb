# %% [markdown]
# Question
#
# Write a program that accepts a comma-separated sequence of words as input and prints the words in alphabetical order as a comma-separated sequence.
#
# Input
#
# A comma-separated sequence of words.
#
# Output
#
# The input words sorted alphabetically and printed as a comma-separated sequence.
#
# Example
#
# Input
#
# without,hello,bag,world
#
# Output
#
# bag,hello,without,world

# %%
s=['without','hello','bag','world']
s.sort()
x=','.join(s)
x.upper()
# Out:
# 'BAG,HELLO,WITHOUT,WORLD'
